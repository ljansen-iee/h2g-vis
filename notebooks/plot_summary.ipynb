# %% [markdown]
# # Plot Summary
#
# Create publication-ready visualizations of PyPSA optimization results including energy balances, installed capacities, and system costs.
#
# **How to use:**
# 1. Run `make_stats_dict.py` to extract statistics from network files
# 2. Update `plot_summary.yaml` with your experiment configuration (countries, years, scenarios)
# 3. Execute cells below to generate all plots automatically
#
# **Configuration:** Edit `plot_summary.yaml` to switch between experiments, filter scenarios, or adjust plot styling without changing code.
#
# **Environment:** Install `envs/pypsa-earth-vis.yaml`

# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import pandas as pd
idx_slice = pd.IndexSlice
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=DeprecationWarning)
import plotly.express as px

# import sys
# sys.path.append('../scripts')
from plot_helpers import (
    chdir_to_root_dir,
    read_stats_dict,
    prepare_dataframe,
    rename_electricity, 
    rename_h2,
    rename_gas,
    rename_oil,
    rename_co2,
    rename_costs,
    colors,
    save_plotly_fig,
    get_scen_col_function,
    apply_standard_styling,
    plot_energy_balance,
    plot_capacity,
    load_plot_config
)

chdir_to_root_dir()

# %%
# Load configuration from YAML file
yaml_config = load_plot_config()

# Extract configuration
RUN_NAME_PREFIX = yaml_config['run']['name_prefix']
SUMMARY_VERSION = yaml_config['run']['summary_version']
SDIR = Path.cwd() / "results" / f"{RUN_NAME_PREFIX}_summary_{SUMMARY_VERSION}"
SDIR.mkdir(exist_ok=True, parents=True)

COUNTRIES = yaml_config['data']['countries']
YEARS = yaml_config['data']['years']
INDEX_LEVELS_TO_DROP = yaml_config['data']['index_levels_to_drop']

# Build index group
IDX_GROUP = idx_slice[[RUN_NAME_PREFIX], :, COUNTRIES, YEARS]
IDX_GROUP_NAME = "".join(COUNTRIES) + "_MAIN"

print(f"Index Group Name: {IDX_GROUP_NAME}")
print(f"Index Group: {IDX_GROUP}")

# Scenario filtering
SCEN_FILTER = yaml_config['data']['scen_filter']
scen_order = yaml_config['data']['scen_order']

# Get scenario column function
scen_col_func_name = yaml_config['data']['scen_col_function']
set_scen_col = get_scen_col_function(scen_col_func_name)
print(f"Using scenario column function: {scen_col_func_name}")

# Plot dimensions
width = yaml_config['plot']['width']
heights = yaml_config['plot']['heights']

# Default figure kwargs
fig_kwargs = yaml_config['plot']['default_kwargs'].copy()
fig_kwargs['width'] = width
fig_kwargs['height'] = heights['medium']

print(f"\nConfiguration loaded successfully!")
print(f"Countries: {COUNTRIES}")
print(f"Years: {YEARS}")
print(f"Scenario filter: {SCEN_FILTER if SCEN_FILTER else 'None (show all)'}")
# Out:
# Index Group Name: CD_MAIN
# Index Group: (['scenarios_H2G'], slice(None, None, None), ['CD'], [2035])
# Using scenario column function: H2G
#
# Configuration loaded successfully!
# Countries: ['CD']
# Years: [2035]
# Scenario filter: None (show all)

# %%
# Load data dictionaries using configuration
balance_keys = yaml_config['carriers']['balance']
capacity_keys = yaml_config['carriers']['capacity']
cost_keys = yaml_config['carriers']['costs']

balance_dict = read_stats_dict("balance_dict", SDIR, keys=balance_keys)
optimal_capacity_dict = read_stats_dict("optimal_capacity_dict", SDIR, keys=capacity_keys)
costs_dict = read_stats_dict("costs_dict", SDIR, keys=cost_keys)

print(f"Loaded balance data for: {balance_keys}")
print(f"Loaded capacity data for: {capacity_keys}")
print(f"Loaded cost data for: {cost_keys}")
# Out:
# Imported AC from /mnt/data/gsa/pypsa-earth-lukas/results/scenarios_H2G_summary_v2/balance_dict_AC.csv
# Imported H2 from /mnt/data/gsa/pypsa-earth-lukas/results/scenarios_H2G_summary_v2/balance_dict_H2.csv
# Imported oil from /mnt/data/gsa/pypsa-earth-lukas/results/scenarios_H2G_summary_v2/balance_dict_oil.csv
# Imported gas from /mnt/data/gsa/pypsa-earth-lukas/results/scenarios_H2G_summary_v2/balance_dict_gas.csv
# Imported co2 stored from /mnt/data/gsa/pypsa-earth-lukas/results/scenarios_H2G_summary_v2/balance_dict_co2 stored.csv
# Imported co2 from /mnt/data/gsa/pypsa-earth-lukas/results/scenarios_H2G_summary_v2/balance_dict_co2.csv
# Imported AC from /mnt/data/gsa/pypsa-earth-lukas/results/scenarios_H2G_summary_v2/optimal_capacity_dict_AC.csv
# Imported H2 from /mnt/data/gsa/pypsa-earth-lukas/results/scenarios_H2G_summary_v2/optimal_capacity_dict_H2.csv
# Imported capex from /mnt/data/gsa/pypsa-earth-lukas/results/scenarios_H2G_summary_v2/costs_dict_capex.csv
# Imported opex from /mnt/data/gsa/pypsa-earth-lukas/results/scenarios_H2G_summary_v2/costs_dict_opex.csv
# Loaded balance data for: ['AC', 'H2', 'oil', 'gas', 'co2 stored', 'co2']
# Loaded capacity data for: ['AC', 'H2']
# Loaded cost data for: ['capex', 'opex']

# %% [markdown]
# ## Plots

# %%
plot_config = {
    'idx_group': IDX_GROUP,
    'idx_group_name': IDX_GROUP_NAME,
    'index_levels_to_drop': INDEX_LEVELS_TO_DROP,
    'set_scen_col_func': set_scen_col,
    'scen_filter': SCEN_FILTER,
    'scen_order': scen_order,
    'fig_kwargs': fig_kwargs,
    'heights': heights,
}

# %% [markdown]
# ### Electricity Supply

# %%
plot_config['chart_config'] = yaml_config['charts']['electricity_supply']

fig, df = plot_energy_balance(
    carrier="AC",
    balance_dict=balance_dict,
    config=plot_config,
    rename_function=rename_electricity,
    show_supply=True,
    save_dir=SDIR
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="efac59d7-3617-4eeb-9e3f-68f1abe18418" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("efac59d7-3617-4eeb-9e3f-68f1abe18418")) {                    Plotly.newPlot(                        "efac59d7-3617-4eeb-9e3f-68f1abe18418",                        [{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar PV","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar PV","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAIEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAIEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hydro","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Hydro","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzH0A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzH0A="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 turbine","marker":{"color":"#f08591","pattern":{"shape":""}},"name":"H2 turbine","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMIEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMIEA="},"yaxis":"y","type":"bar","textangle":0},{"hoverinfo":"skip","mode":"text","showlegend":false,"text":["24"],"textfont":{"color":"black","size":14,"weight":"bold"},"textposition":"top center","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzOUA="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.88888888 ...

# %% [markdown]
# ### Electricity Demand

# %%
plot_config['chart_config'] = yaml_config['charts']['electricity_demand']

fig, df = plot_energy_balance(
    carrier="AC",
    balance_dict=balance_dict,
    config=plot_config,
    rename_function=rename_electricity,
    show_supply=False,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="56d75728-621c-4680-84ae-e17903aee533" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("56d75728-621c-4680-84ae-e17903aee533")) {                    Plotly.newPlot(                        "56d75728-621c-4680-84ae-e17903aee533",                        [{"hovertemplate":"=%{x}\u003cbr\u003eElectricity consumption [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industry","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity consumption [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Commerce","marker":{"color":"#008598","pattern":{"shape":""}},"name":"Commerce","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZm5j8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZm5j8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity consumption [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Residential","marker":{"color":"#39c1cd","pattern":{"shape":""}},"name":"Residential","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmLEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmLEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity consumption [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Battery","marker":{"color":"#836bad","pattern":{"shape":""}},"name":"Battery","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZyT8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZyT8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity consumption [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 Electrolysis","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz8z8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz8z8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity consumption [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"industry","marker":{"color":"#9467BD","pattern":{"shape":""}},"name":"industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzIUA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzIUA="},"yaxis":"y","type":"bar","textangle":0},{"hoverinfo":"skip","mode":"text","showlegend":false,"text":["25"],"textfont":{"color":"black","size":14,"weight":"bold"},"textposition":"top center","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAOkA="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type" ...

# %% [markdown]
# ### Electricity Installed Capacity

# %%
plot_config['chart_config'] = yaml_config['charts']['electricity_capacity']

fig, df = plot_capacity(
    carrier="AC",
    capacity_dict=optimal_capacity_dict,
    config=plot_config,
    rename_function=rename_electricity,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="b161fb49-6e2d-4cc7-bc31-3d701fdcb87a" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b161fb49-6e2d-4cc7-bc31-3d701fdcb87a")) {                    Plotly.newPlot(                        "b161fb49-6e2d-4cc7-bc31-3d701fdcb87a",                        [{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity [GW\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar PV","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar PV","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAGkA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAGkA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity [GW\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hydro","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Hydro","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZBUA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZBUA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity [GW\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas turbines","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Gas turbines","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity [GW\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Battery","marker":{"color":"#836bad","pattern":{"shape":""}},"name":"Battery","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAAEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity [GW\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 turbine","marker":{"color":"#f08591","pattern":{"shape":""}},"name":"H2 turbine","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZm9j8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZm9j8="},"yaxis":"y","type":"bar","textangle":0},{"hoverinfo":"skip","mode":"text","showlegend":false,"text":["13"],"textfont":{"color":"black","size":14,"weight":"bold"},"textposition":"top center","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmK0A="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth ...

# %% [markdown]
# ### Hydrogen Balance

# %%
plot_config['chart_config'] = yaml_config['charts']['hydrogen_balance']

fig, df = plot_energy_balance(
    carrier="H2",
    balance_dict=balance_dict,
    config=plot_config,
    rename_function=rename_h2,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="b0a5dcc1-0978-48ce-ba2d-d66b50fdf7c9" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b0a5dcc1-0978-48ce-ba2d-d66b50fdf7c9")) {                    Plotly.newPlot(                        "b0a5dcc1-0978-48ce-ba2d-d66b50fdf7c9",                        [{"hovertemplate":"=%{x}\u003cbr\u003eGH2 balance [TWh\u003csub\u003eH2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Production","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZm5j8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZm5j8="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Production"}},{"hovertemplate":"=%{x}\u003cbr\u003eGH2 balance [TWh\u003csub\u003eH2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Fuel Cell","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZub8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZub8="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Consumption"}},{"hovertemplate":"=%{x}\u003cbr\u003eGH2 balance [TWh\u003csub\u003eH2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#f08591","pattern":{"shape":""}},"name":"H2 turbine","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMxMNMA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMxMNMA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Consumption"}},{"hovertemplate":"=%{x}\u003cbr\u003eGH2 balance [TWh\u003csub\u003eH2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#a8508c","pattern":{"shape":""}},"name":"FT Synthesis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZKMA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZKMA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Consumption"}},{"hovertemplate":"=%{x}\u003cbr\u003eGH2 balance [TWh\u003csub\u003eH2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#4CC2A6","pattern":{"shape":""}},"name":"H2 export","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmCsA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmCsA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Consumption"}},{"hovertemplate":"=%{x}\u003cbr\u003eGH2 balance [TWh\u003csub\u003eH2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Production","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Steam reforming","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZAUA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZAUA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Production"}},{"hovertemplate":"=%{x}\u003cbr\u003eGH2 balance [TWh\u003csub\u003eH2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Production","marker":{"color":"#9467BD","pattern":{"shape":""} ...

# %% [markdown]
# ### Hydrogen Installed Capacity

# %%
plot_config['chart_config'] = yaml_config['charts']['hydrogen_capacity']

fig, df = plot_capacity(
    carrier="H2",
    capacity_dict=optimal_capacity_dict,
    config=plot_config,
    rename_function=rename_h2,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="79cd9b17-095b-450e-8481-3b87a0e9cdc3" class="plotly-graph-div" style="height:300px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("79cd9b17-095b-450e-8481-3b87a0e9cdc3")) {                    Plotly.newPlot(                        "79cd9b17-095b-450e-8481-3b87a0e9cdc3",                        [{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity [GW\u003csub\u003eH2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 Electrolysis","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"textposition":"inside","texttemplate":"%{y:.1f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity [GW\u003csub\u003eH2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Steam reforming","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Steam reforming","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz0z8="},"textposition":"inside","texttemplate":"%{y:.1f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz0z8="},"yaxis":"y","type":"bar","textangle":0},{"hoverinfo":"skip","mode":"text","showlegend":false,"text":["0"],"textfont":{"color":"black","size":14,"weight":"bold"},"textposition":"top center","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZm9j8="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type": ...

# %% [markdown]
# ### Liquid Fuel Balance

# %%
plot_config['chart_config'] = yaml_config['charts']['liquid_fuel_balance']

fig, df = plot_energy_balance(
    carrier="oil",
    balance_dict=balance_dict,
    config=plot_config,
    rename_function=rename_oil,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="b6d2ebf4-a335-4404-82f3-75d7dbe93304" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b6d2ebf4-a335-4404-82f3-75d7dbe93304")) {                    Plotly.newPlot(                        "b6d2ebf4-a335-4404-82f3-75d7dbe93304",                        [{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance [TWh]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Production","marker":{"color":"#1c3f52","pattern":{"shape":""}},"name":"Fossil fuel import","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZ8T8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZ8T8="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Production"}},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance [TWh]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Production","marker":{"color":"#a8508c","pattern":{"shape":""}},"name":"FT Synthesis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMI0A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMI0A="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Production"}},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance [TWh]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#669db2","pattern":{"shape":""}},"name":"Land transport","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmIcA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmIcA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Consumption"}},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance [TWh]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Aviation","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmAsA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmAsA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Consumption"}},{"hoverinfo":"skip","mode":"text","showlegend":false,"text":["11"],"textfont":{"color":"black","size":14,"weight":"bold"},"textposition":"top center","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAMEA="},"yaxis":"y","type":"scatter"},{"hoverinfo":"skip","mode":"text","showlegend":false,"text":[""],"textfont":{"color":"black","size":14,"weight":"bold"},"textposition":"bottom center","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAGEA="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks": ...

# %% [markdown]
# ### CH4 Balance

# %%
plot_config['chart_config'] = yaml_config['charts']['ch4_balance']

fig, df = plot_energy_balance(
    carrier="gas",
    balance_dict=balance_dict,
    config=plot_config,
    rename_function=rename_gas,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="65820b44-57e5-4cfc-b946-be8096cfda5a" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("65820b44-57e5-4cfc-b946-be8096cfda5a")) {                    Plotly.newPlot(                        "65820b44-57e5-4cfc-b946-be8096cfda5a",                        [{"hovertemplate":"=%{x}\u003cbr\u003eCH4 balance [TWh]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#17BECF","pattern":{"shape":""}},"name":"Steam reforming","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAACMA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAACMA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Consumption"}},{"hovertemplate":"=%{x}\u003cbr\u003eCH4 balance [TWh]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Production","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"biogas to gas","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAACEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAACEA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Production"}},{"hoverinfo":"skip","mode":"text","showlegend":false,"text":["3"],"textfont":{"color":"black","size":14,"weight":"bold"},"textposition":"top center","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAIEA="},"yaxis":"y","type":"scatter"},{"hoverinfo":"skip","mode":"text","showlegend":false,"text":[""],"textfont":{"color":"black","size":14,"weight":"bold"},"textposition":"bottom center","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAMA="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222 ...

# %% [markdown]
# ### CO2 Capture and Usage

# %%
plot_config['chart_config'] = yaml_config['charts']['co2_stored_balance']

fig, df = plot_energy_balance(
    carrier="co2 stored",
    balance_dict=balance_dict,
    config=plot_config,
    rename_function=rename_co2,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="10c399f7-fd8e-48ff-a2e6-654ee429b327" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("10c399f7-fd8e-48ff-a2e6-654ee429b327")) {                    Plotly.newPlot(                        "10c399f7-fd8e-48ff-a2e6-654ee429b327",                        [{"hovertemplate":"variable=FT Synthesis\u003cbr\u003e=%{x}\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FT Synthesis","marker":{"color":"#a8508c","pattern":{"shape":""}},"name":"FT Synthesis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAABMA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAABMA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Biomass for industry with CC\u003cbr\u003e=%{x}\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Biomass for industry with CC","marker":{"color":"#9467BD","pattern":{"shape":""}},"name":"Biomass for industry with CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz0z8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz0z8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Carbon capture\u003cbr\u003e=%{x}\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Carbon capture","marker":{"color":"#8C564B","pattern":{"shape":""}},"name":"Carbon capture","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz078="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz078="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Process emissions with CC\u003cbr\u003e=%{x}\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Process emissions with CC","marker":{"color":"#E377C2","pattern":{"shape":""}},"name":"Process emissions with CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAABEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAABEA="},"yaxis":"y","type":"bar","textangle":0}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"] ...

# %% [markdown]
# ### CO2 Emissions

# %%
plot_config['chart_config'] = yaml_config['charts']['co2_emissions']

fig, df = plot_energy_balance(
    carrier="co2",
    balance_dict=balance_dict,
    config=plot_config,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="e4f04a8e-bbb0-4af3-86cc-e751a899db1d" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e4f04a8e-bbb0-4af3-86cc-e751a899db1d")) {                    Plotly.newPlot(                        "e4f04a8e-bbb0-4af3-86cc-e751a899db1d",                        [{"hovertemplate":"variable=SMR\u003cbr\u003e=%{x}\u003cbr\u003eCO2 emissions [Mt\u003csub\u003eCO2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SMR","marker":{"color":"#7F7F7F","pattern":{"shape":""}},"name":"SMR","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz4z8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz4z8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=biogas to gas\u003cbr\u003e=%{x}\u003cbr\u003eCO2 emissions [Mt\u003csub\u003eCO2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"biogas to gas","marker":{"color":"#BCBD22","pattern":{"shape":""}},"name":"biogas to gas","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz478="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz478="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=co2\u003cbr\u003e=%{x}\u003cbr\u003eCO2 emissions [Mt\u003csub\u003eCO2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"co2","marker":{"color":"#17BECF","pattern":{"shape":""}},"name":"co2","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZBcA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZBcA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=land transport oil emissions\u003cbr\u003e=%{x}\u003cbr\u003eCO2 emissions [Mt\u003csub\u003eCO2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"land transport oil emissions","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"land transport oil emissions","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZAUA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZAUA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=oil emissions\u003cbr\u003e=%{x}\u003cbr\u003eCO2 emissions [Mt\u003csub\u003eCO2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"oil emissions","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"oil emissions","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz4z8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz4z8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=process emissions CC\u003cbr\u003e=%{x}\u003cbr\u003eCO2 emissions [Mt\u003csub\u003eCO2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"process emissions CC","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"process emissions CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZyT8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZyT8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=solid biomass for industry CC\u003cbr\u003e=%{x}\u003cbr\u003eCO2 emissions [Mt\u003csub\u003eCO2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"solid ...

# %% [markdown]
# ### System Costs

# %%
plot_config['chart_config'] = yaml_config['charts'].get('system_costs', {
    'title': 'System Costs',
    'save_name': 'system_costs_billion_eur',
    'chart_type': 'bar_with_negatives'
})
stats_df = pd.concat([costs_dict["capex"], costs_dict["opex"]], axis=0)
df = prepare_dataframe(stats_df, IDX_GROUP, INDEX_LEVELS_TO_DROP, set_scen_col)
df.variable = df.variable.map(rename_costs)
df = df[df["value"] != 0]
df = df.query("scen in @SCEN_FILTER") if SCEN_FILTER else df

fig_kwargs_costs = plot_config['fig_kwargs'].copy()
fig_kwargs_costs['height'] = plot_config['heights']['large']

fig = px.bar(
    df,
    **fig_kwargs_costs,
    color_discrete_map=colors["costs"],
    category_orders={
        "variable": list(colors["costs"].keys()),
        "scen": scen_order
    },
    labels={
        "value": "System costs [billion EUR/year]",
        "year": "",
        "scen": ""
    }
)

chart_type = plot_config['chart_config'].get('chart_type', 'bar') #'bar_with_negatives'
fig = apply_standard_styling(fig, chart_type, plot_config['chart_config'])

save_name = plot_config['chart_config'].get('save_name', 'system_costs')
save_plotly_fig(df, fig, SDIR, f"{IDX_GROUP_NAME}_{save_name}")

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="6601d773-c929-4f4b-a6cb-335e3f89902c" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6601d773-c929-4f4b-a6cb-335e3f89902c")) {                    Plotly.newPlot(                        "6601d773-c929-4f4b-a6cb-335e3f89902c",                        [{"hovertemplate":"variable=Solar\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs [billion EUR\u002fyear]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Transmission line\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs [billion EUR\u002fyear]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Transmission line","marker":{"color":"#4cc2a6","pattern":{"shape":""}},"name":"Transmission line","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzM7D8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzM7D8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Battery\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs [billion EUR\u002fyear]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Battery","marker":{"color":"#836bad","pattern":{"shape":""}},"name":"Battery","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Oil\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs [billion EUR\u002fyear]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oil","marker":{"color":"#C0C0C0","pattern":{"shape":""}},"name":"Oil","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Carbon capture\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs [billion EUR\u002fyear]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Carbon capture","marker":{"color":"#7c154d","pattern":{"shape":""}},"name":"Carbon capture","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Residential\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs [billion EUR\u002fyear]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Residential","marker":{"color":"#E377C2","pattern":{"shape":""}},"name":"Residential","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=FT Synthesis\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs [billion EUR\u002fyear]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FT Synthesis","marker":{"color":"#7F7F7F","pattern":{"shape":""}},"name":"FT Synthesis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["NZ3.33"],"xax ...
